# %%
from __future__ import division
from __future__ import unicode_literals
import pandas as pd
import numpy as np
import json
import os, glob
import scipy, scipy.io


import matplotlib
from matplotlib import *
from matplotlib import pyplot as plt
import itertools
from mpl_toolkits.axes_grid1 import make_axes_locatable

from itertools import compress

import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')

# pretty charting
import seaborn as sns
sns.set_palette('muted')
sns.set_style('darkgrid')

# %matplotlib inline

# %%
def loadmat(filename):
    '''
    this function should be called instead of direct spio.loadmat
    as it cures the problem of not properly recovering python dictionaries
    from mat files. It calls the function check keys to cure all entries
    which are still mat-objects
    '''
    data = scipy.io.loadmat(filename, struct_as_record=False, squeeze_me=True)
    return _check_keys(data)

def _check_keys(dict):
    '''
    checks if entries in dictionary are mat-objects. If yes
    todict is called to change them to nested dictionaries
    '''
    for key in dict:
        if isinstance(dict[key], scipy.io.matlab.mio5_params.mat_struct):
            dict[key] = _todict(dict[key])
    return dict        

def _todict(matobj):
    '''
    A recursive function which constructs from matobjects nested dictionaries
    '''
    dict = {}
    for strg in matobj._fieldnames:
        elem = matobj.__dict__[strg]
        if isinstance(elem, scipy.io.matlab.mio5_params.mat_struct):
            dict[strg] = _todict(elem)
        elif isinstance(elem,np.ndarray):
            dict[strg] = _tolist(elem)
        else:
            dict[strg] = elem
    return dict

def _tolist(ndarray):
    '''
    A recursive function which constructs lists from cellarrays 
    (which are loaded as numpy ndarrays), recursing into the elements
    if they contain matobjects.
    '''
    elem_list = []            
    for sub_elem in ndarray:
        if isinstance(sub_elem, scipy.io.matlab.mio5_params.mat_struct):
            elem_list.append(_todict(sub_elem))
        elif isinstance(sub_elem,np.ndarray):
            elem_list.append(_tolist(sub_elem))
        else:
            elem_list.append(sub_elem)
    return elem_list

def convertMatToJSON(matData, fileName):
    for key in matData.keys():
        if (type(matData[key])) is np.ndarray:
            serializedData = pickle.dumps(matData[key], protocol=0) # protocol 0 is printable ASCII
            jsonData[key] = serializedData
        else:
            jsonData[key] = matData[key]

    with contextlib.closing(bz2.BZ2File(fileName, 'wb')) as f:
        json.dump(jsonData, f)
        
def degreeofagree(ezset, cezset, allset, metric='default'):
    if metric == 'default':
        notcez = list(set(allset) - set(cezset))
        cez_int_eez = list(set(cezset) & set(ezset))
        notcez_int_eez = list(set(notcez) & set(ezset))

        term1 = len(cez_int_eez) / len(cezset)
        term2 = len(notcez_int_eez) / len(notcez)

        doa = term1 - term2
    elif metric == 'jaccard':
        cez_int_eez = list(set(cezset) &  set(ezset))
        cez_and_eez = list(set(cezset).union(ezset))
        
        doa = len(cez_int_eez) / len(cez_and_eez)
        
    return doa

# %%
pats = ['pt1', 'pt2', 'pt3', 'pt6', 'pt7', 'pt8', 'pt10', 'pt13', 'pt14', 'pt15', 'pt16']
for pat in pats:
    dataDir = '/Users/adam2392/Documents/adamli/fragility_dataanalysis/' + \
        'figures/fragilityStats/notchfilter/perturbationC_win250_step125_radius1.5/ictal/' + pat
    filelist = os.listdir(dataDir)
    
    # thresholds to set on the preictal, ictal times of coefficient of variation / other frag stats
    thresholds = [0.7, 0.8, 0.9, 0.95, 0.99]

    nih_doas = np.zeros((len(filelist), len(thresholds)))
    nih_ezsets = np.array(())
    nih_pats = []
    # Load each dataset's fragility statistics results
    for idx, fil in enumerate(filelist):
        datastruct = loadmat(os.path.join(dataDir, fil))
        features = datastruct['features_struct']

        colnames = features.keys()
        for col in colnames:
            try:
                features[col] = features[col]/max(features[col])
            except:
                1+1
    #             print col, " does not work"
        # extract all the fragility stats
        patient = features['patient']
        cfvar_time = features['cfvar_time']
        cfvar_chan = features['cfvar_chan']
        channels = features['included_labels']
        cezset = features['ezone_labels']

        # only if the dataset was ictal
        rowsum = features['rowsum']
        ez_90thresh = features['ez_90thresh_set']
        ez_95thresh = features['ez_95thresh_set']
        precfvar_chan = features['precfvar_chan']
        postcfvar_chan = features['postcfvar_chan']

        # extract the clinical meta data for this patient

        # go through each threshold and determine set of electrodes within EZ set 
        pat_doas = np.zeros((1, len(thresholds)))
        pat_ezsets = []
        for jdx, threshold in enumerate(thresholds):
            # get the indices that pass threshold for coefficient of variation
            cfvar_threshed_ind = postcfvar_chan >= threshold

            # get the actual cv and the electrode name
            cfvar_threshed = list(compress(postcfvar_chan, cfvar_threshed_ind))
            ezset = list(compress(channels, cfvar_threshed_ind))

            # compute doa
            doa_threshold = degreeofagree(ezset, cezset, channels)

            # store the channel for this threshold
            pat_doas[0, jdx] = doa_threshold
            pat_ezsets.append(np.array(ezset))

        # convert the patient ez sets into an np array
        pat_ezsets = np.array(pat_ezsets).reshape(len(thresholds), 1)

        # store the pats in a list
        nih_pats.append(patient)

        # store the pat ez sets 
        if nih_ezsets.size == 0:
            nih_ezsets = pat_ezsets
        else:
            nih_ezsets = np.append(nih_ezsets, pat_ezsets, axis=1)

        # store the pat doa into the center doa array
        nih_doas[idx, :] = pat_doas

    # print nih_pats
    # print nih_ezsets
    # print nih_doas
#     print pat
#     print nih_ezsets
    
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(211)
    plt.title('NIH Degree of Agreement Coefficient of Var for ' + pat)
    plt.xlabel('Threshold')
    plt.ylabel('Degree of Agreement')
    g = sns.boxplot(pd.DataFrame(nih_doas))
    xticklabels = g.get_xticklabels()
    g.set_xticklabels([str(threshold) for threshold in thresholds])
# Out:
# pt1
# [[array([u'G12', u'ATT1', u'ILT1', u'ILT4'],
#       dtype='<U4')
#   array([u'G1', u'G2', u'G13', u'G12', u'G27', u'IF5', u'ILT1', u'ILT2',
#        u'ILT3', u'ILT4', u'MLT4'],
#       dtype='<U4')
#   array([u'ILT1', u'ILT2', u'ILT4'],
#       dtype='<U4')]
#  [array([u'G12', u'ILT1'],
#       dtype='<U4')
#   array([u'G1', u'G13', u'G12', u'ILT1', u'ILT2', u'MLT4'],
#       dtype='<U4')
#   array([u'ILT1', u'ILT2'],
#       dtype='<U4')]
#  [array([u'ILT1'],
#       dtype='<U4')
#   array([u'G12', u'ILT1', u'ILT2'],
#       dtype='<U4')
#   array([u'ILT1'],
#       dtype='<U4')]
#  [array([u'ILT1'],
#       dtype='<U4')
#   array([u'G12', u'ILT1'],
#       dtype='<U4')
#   array([u'ILT1'],
#       dtype='<U4')]
#  [array([u'ILT1'],
#       dtype='<U4') array([u'ILT1'],
#       dtype='<U4')
#   array([u'ILT1'],
#       dtype='<U4')]]
# pt2
# [[ array([u'G1', u'G2', u'G4', u'G10', u'G14', u'G15', u'G18', u'G21', u'G23',
#        u'G11', u'G24', u'G29', u'G31', u'AST3', u'AST4', u'MST1', u'MST2',
#        u'MST3', u'PST2', u'AST1', u'AST2'],
#       dtype='<U4')
#   array([u'G2', u'G8', u'G18', u'G21', u'G23', u'G32', u'TT1', u'TT4',
#        u'TT5', u'AST3', u'MST1', u'PST1', u'OF2', u'OF3', u'OF4', u'LF1',
#        u'LF2', u'LF3', u'LF4', u'LF5', u'LF6', u'AST1', u'AST2', u'LP6'],
#       dtype='<U4')
#   array([u'G1', u'G2', u'G3', u'G4', u'G9', u'G10', u'G14', u'G15', u'G16',
#        u'G18', u'G19', u'G22', u'G23', u'G11', u'G12', u'G26', u'G27',
#        u'G28', u'TT4', u'TT5', u'AST3', u'AST4', u'MST2', u'MST3', u'MST4',
#        u'PST4', u'OF1', u'OF2', u'OF3', u'OF4', u'LF1', u'LF2', u'LF3',
#        u'LF4', u'LF5', u'LF6', u'AST1', u'AST2', u'LP1', u'LP2', u'LP3',
#        u'LP4', u'LP5', u'LP6'],
#       dtype='<U4')]
#  [ array([u'G1', u'G2', u'G10', u'G15', u'G18', u'G23', u'G24', u'G31',
#        u'AST3', u'PST2'],
#       dtype='<U4')
#   array([u'G2', u'G8', u'G23', u'MST1', u'PST1', u'OF2', u'OF3', u'LF1',
#        u'LF2', u'LF3', u'LF5', u'LF6'],
#       dtype='<U4')
#   array([u'G1', u'G2', u'G3', u'G4', u'G10', u'G14', u'G15', u'G18', u'G19',
#        u'G22', u'G23', u'G11', u'G26', u'TT4', u'TT5', u'AST3', u'AST4',
#        u'MST2', u'PST4', u'OF1', u'OF2', u'OF3', u'OF4', u'LF1', u'LF3',
#        u'LF4', u'LF5', u'LF6', u'AST2'],
#       dtype='<U4')]
#  [array([u'G2', u'G15', u'G23'],
#       dtype='<U3')
#   array([u'G23', u'PST1', u'OF3', u'LF5', u'LF6'],
#       dtype='<U4')
#   array([u'G1', u'G2', u'G10', u'G14', u'G18', u'G23', u'G11', u'AST3',
#        u'AST4', u'OF3', u'OF4', u'LF4', u'AST2'],
#       dtype='<U4')]
#  [array([u'G15', u'G23'],
#       dtype='<U3')
#   array([u'PST1'],
#       dtype='<U4')
#   array([u'G2', u'G10', u'AST3', u'AST4', u'AST2'],
#       dtype='<U4')]
#  [array([u'G15'],
#       dtype='<U3') array([u'PST1'],
#       dtype='<U4')
#   array([u'AST2'],
#       dtype='<U4')]]
# /Users/adam2392/.virtualenvs/tvb/lib/python2.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide
# pt3
# [[ array([u'AST1', u'AST3', u'AST4', u'MST1', u'MST3', u'PST2', u'PST3',
#        u'SFP1', u'FG32'],
#       dtype='<U4')
#   array([u'AST1', u'TG24', u'AST3', u'PST1', u'PST3'],
#       dtype='<U4')]
#  [array([u'AST1', u'AST3', u'PST2', u'PST3'],
#       dtype='<U4')
#   array([u'AST1', u'PST3'],
#       dtype='<U4')]
#  [array([u'AST1'],
#       dtype='<U4') array([u'AST1'],
#       dtype='<U4')]
#  [array([u'AST1'],
#       dtype='<U4') array([u'AST1'],
#       dtype='<U4')]
#  [array([u'AST1'],
#       dtype='<U4') array([u'AST1'],
#       dtype='<U4')]]
# pt6
# [[array([u'RPLT2', u'RPLT3', u'RPLT4'],
#       dtype='<U5')
#   array([u'RPLT1', u'RPH2'],
#       dtype='<U5') u'RPLT1']
#  [array([u'RPLT2', u'RPLT4'],
#       dtype='<U5')
#   array([u'RPLT1'],
#       dtype='<U5') u'RPLT1']
#  [array([u'RPLT4'],
#       dtype='<U5') array([u'RPLT1'],
#       dtype='<U5')
#   u'RPLT1']
#  [array([u'RPLT4'],
#       dtype='<U5') array([u'RPLT1'],
#       dtype='<U5')
#   u'RPLT1']
#  [array([u'RPLT4'],
#       dtype='<U5') array([u'RPLT1'],
#       dtype='<U5')
#   u'RPLT1']]
# pt7
# [[ array([u'LFP3', u'G7', u'G13', u'G14', u'G15', u'G16', u'G22', u'G23',
#        u'G24', u'G28', u'G31', u'G32', u'G38', u'G39', u'G40', u'G44',
#        u'G52', u'G53', u'G54', u'G55', u'G63', u'G64', u'PF3', u'PF4',
#        u'PF5', u'PF6', u'PT3'],
#       dtype='<U4')
#   array([u'LFP3', u'G6', u'G7', u'G13', u'G14', u'G15', u'G16', u'G21',
#        u'G22', u'G23', u'G24', u'G27', u'G28', u'G31', u'G32', u'G37',
#        u'G38', u'G39', u'G40', u'G43', u'G44', u'G52', u'G53', u'G54',
#        u'G55', u'G56', u'G63', u'G64', u'PF3', u'PF4', u'PF5', u'PF6',
#        u'AT4', u'PT2', u'PT3'],
#       dtype='<U4')
#   array([u'MT1', u'MT2', u'MT3', u'G7', u'G8', u'G15', u'G16', u'G22',
#        u'G23', u'G24', u'G38', u'PF1', u'PF3', u'PF4', u'PF6', u'AT1',
#        u'AT2', u'AT3', u'AT4', u'AT5', u'PT1', u'PT2', u'PT3', u'PT4',
#        u'PT6'],
#       dtype='<U3')]
#  [ array([u'G13', u'G14', u'G16', u'G23', u'G28', u'G31', u'G32', u'G38',
#        u'G40', u'G44', u'G63'],
#       dtype='<U3')
#   array([u'G22', u'G28', u'G31', u'G32', u'G38', u'G54'],
#       dtype='<U3')
#   array([u'MT2', u'PF1', u'PF3', u'PF6', u'AT1', u'AT4', u'PT2', u'PT3',
#        u'PT4'],
#       dtype='<U3')]
#  [array([u'G16', u'G31', u'G32'],
#       dtype='<U3')
#   array([u'G31', u'G32', u'G38'],
#       dtype='<U3')
#   array([u'PF3', u'PF6', u'AT4', u'PT2'],
#       dtype='<U3')]
#  [array([u'G31', u'G32'],
#       dtype='<U3')
#   array([u'G31', u'G32'],
#       dtype='<U3')
#   array([u'PF6', u'AT4'],
#       dtype='<U3')]
#  [array([u'G32'],
#       dtype='<U3') array([u'G31'],
#       dtype='<U3')
#   array([u'PF6'],
#       dtype='<U3')]]
# pt8
# [[ array([u'PST2', u'PPST2', u'PPST3', u'PPST4', u'G18', u'G21', u'G22',
#        u'G23', u'G15', u'G4', u'G6', u'TO4', u'TO2', u'TO1'],
#       dtype='<U5')
#   array([u'PPST3', u'PPST4', u'G30', u'G21', u'G22', u'G23', u'G4', u'G6',
#        u'TO5', u'TO4', u'TO3'],
#       dtype='<U5')
#   array([u'PPST2', u'PPST3', u'PPST4', u'G21', u'G22', u'G23', u'G4', u'G6',
#        u'G8', u'TO4', u'TO2'],
#       dtype='<U5')]
#  [ array([u'PPST2', u'PPST3', u'G18', u'G21', u'G22', u'G23', u'G4', u'G6',
#        u'TO4'],
#       dtype='<U5')
#   array([u'PPST3', u'G21', u'G22', u'G23', u'G6', u'TO5', u'TO4'],
#       dtype='<U5')
#   array([u'PPST2', u'PPST3', u'G21', u'G23', u'G6', u'TO4', u'TO2'],
#       dtype='<U5')]
#  [array([u'PPST2', u'G21', u'G22', u'G23'],
#       dtype='<U5')
#   array([u'G22', u'G23'],
#       dtype='<U3')
#   array([u'PPST2', u'PPST3', u'G23', u'G6'],
#       dtype='<U5')]
#  [array([u'G21', u'G22', u'G23'],
#       dtype='<U3')
#   array([u'G22', u'G23'],
#       dtype='<U3')
#   array([u'PPST2', u'G6'],
#       dtype='<U5')]
#  [array([u'G21'],
#       dtype='<U3') array([u'G23'],
#       dtype='<U3')
#   array([u'G6'],
#       dtype='<U2')]]
# pt10
# [[ array([u'TT5', u'AST4', u'MST3', u'MST4', u'PST4', u'FP36', u'FP37',
#        u'FP46', u'FP47', u'FP48', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8',
#        u'G11', u'G12', u'G13', u'G15', u'G24', u'G28', u'G29', u'G30',
#        u'G31', u'G32'],
#       dtype='<U4')
#   array([u'OF2', u'FP36', u'FP37', u'FP39', u'FP46', u'FP47', u'FP48', u'G3',
#        u'G4', u'G6', u'G7', u'G13', u'G28', u'G29', u'G30', u'G31', u'G32'],
#       dtype='<U4')
#   array([u'OF2', u'OF3', u'AST1', u'FP36', u'FP43', u'G3', u'G4', u'G6',
#        u'G7', u'G11', u'G12', u'G13', u'G20', u'G28', u'G29', u'G30',
#        u'G31', u'G32'],
#       dtype='<U4')]
#  [ array([u'G3', u'G4', u'G6', u'G7', u'G13', u'G15', u'G28', u'G29', u'G30',
#        u'G31'],
#       dtype='<U3')
#   array([u'G28', u'G29', u'G30', u'G31'],
#       dtype='<U3')
#   array([u'AST1', u'G28', u'G29', u'G31'],
#       dtype='<U4')]
#  [array([u'G6', u'G28', u'G29', u'G30', u'G31'],
#       dtype='<U3')
#   array([u'G28'],
#       dtype='<U3')
#   array([u'AST1', u'G31'],
#       dtype='<U4')]
#  [array([u'G29', u'G30'],
#       dtype='<U3')
#   array([u'G28'],
#       dtype='<U3') array([u'AST1'],
#       dtype='<U4')]
#  [array([u'G29', u'G30'],
#       dtype='<U3')
#   array([u'G28'],
#       dtype='<U3') array([u'AST1'],
#       dtype='<U4')]]
# pt13
# [[ array([u'G20', u'G21', u'G28', u'G38', u'G42', u'G43', u'G44', u'G47',
#        u'G49', u'G50', u'G51', u'G52', u'G53', u'G60', u'LF6', u'RPPIH1',
#        u'RPPIH3'],
#       dtype='<U6')
#   array([u'G20', u'G21', u'G38', u'G42', u'G43', u'G44', u'G49', u'G50',
#        u'G51', u'G52', u'G53', u'G57', u'G58', u'G60', u'G62', u'LF6',
#        u'FP6', u'RPPIH1'],
#       dtype='<U6')
#   array([u'G20', u'G21', u'G29', u'G38', u'G42', u'G43', u'G44', u'G49',
#        u'G50', u'G51', u'G52', u'G53', u'G60'],
#       dtype='<U3')
#   array([u'G20', u'G21', u'G29', u'G38', u'G42', u'G43', u'G44', u'G46',
#        u'G47', u'G49', u'G50', u'G51', u'G52', u'G53', u'G60', u'G62'],
#       dtype='<U3')]
#  [array([u'G20', u'G43', u'G44', u'G50', u'G52'],
#       dtype='<U3')
#   array([u'G20', u'G43', u'G44', u'G49', u'G50', u'G52', u'LF6'],
#       dtype='<U3')
#   array([u'G20', u'G21', u'G29', u'G43', u'G44', u'G49', u'G50', u'G52',
#        u'G53'],
#       dtype='<U3')
#   array([u'G20', u'G42', u'G43', u'G44', u'G50', u'G51', u'G52', u'G60'],
#       dtype='<U3')]
#  [array([u'G43', u'G44', u'G50'],
#       dtype='<U3')
#   array([u'G43', u'G50', u'G52', u'LF6'],
#       dtype='<U3')
#   array([u'G43', u'G44', u'G50', u'G52'],
#       dtype='<U3')
#   array([u'G43', u'G44'],
#       dtype='<U3')]
#  [array([u'G50'],
#       dtype='<U3')
#   array([u'G43', u'G50'],
#       dtype='<U3')
#   array([u'G50'],
#       dtype='<U3') array([u'G44'],
#       dtype='<U3')]
#  [array([u'G50'],
#       dtype='<U3') array([u'G43'],
#       dtype='<U3')
#   array([u'G50'],
#       dtype='<U3') array([u'G44'],
#       dtype='<U3')]]
# pt14
# [[ array([u'G16', u'G18', u'G19', u'G20', u'G27', u'PST1', u'PPST1', u'PPST2',
#        u'PT2', u'PT3', u'PT4', u'PT5', u'PT6'],
#       dtype='<U5')
#   array([u'G16', u'PPST1', u'PPST2', u'PT1', u'PT2', u'PT3', u'PT4', u'OF1',
#        u'OF2', u'OF3', u'OF4'],
#       dtype='<U5')
#   array([u'G12', u'G16', u'G18', u'G24', u'MST1', u'MST3', u'PPST1',
#        u'PPST2', u'PT2', u'PT4', u'PT6', u'OF1'],
#       dtype='<U5')]
#  [ array([u'G16', u'G19', u'PPST1', u'PPST2', u'PT2', u'PT3', u'PT5'],
#       dtype='<U5')
#   array([u'G16', u'PT1', u'PT2', u'PT3', u'OF1'],
#       dtype='<U3')
#   array([u'G16', u'G18', u'PT2'],
#       dtype='<U3')]
#  [array([u'G16', u'PT3'],
#       dtype='<U3')
#   array([u'PT1', u'PT3'],
#       dtype='<U3')
#   array([u'G16'],
#       dtype='<U3')]
#  [array([u'PT3'],
#       dtype='<U3') array([u'PT1'],
#       dtype='<U3')
#   array([u'G16'],
#       dtype='<U3')]
#  [array([u'PT3'],
#       dtype='<U3') array([u'PT1'],
#       dtype='<U3')
#   array([u'G16'],
#       dtype='<U3')]]
# pt15
# [[ array([u'G3', u'G4', u'G8', u'G12', u'G15', u'G16', u'G20', u'G21', u'G22',
#        u'G23', u'G27', u'G29', u'G13', u'G14', u'G30', u'G31', u'G32',
#        u'AST1', u'AST2', u'MST3', u'PST1', u'PST3', u'PPST1', u'PPST2',
#        u'TO1', u'TO2', u'TO3', u'TO4', u'TO5', u'TO6', u'LSF1', u'LSF2',
#        u'LSF3'],
#       dtype='<U5')
#   u'PST3'
#   array([u'G3', u'G4', u'G5', u'G8', u'G12', u'G19', u'G20', u'G21', u'G22',
#        u'G23', u'G24', u'G27', u'G28', u'G29', u'G13', u'G30', u'G31',
#        u'G32', u'TT1', u'TT3', u'AST1', u'AST2', u'AST3', u'MST3',
#        u'PPST3', u'PPST4', u'TO1', u'TO3', u'TO5', u'TO6', u'LIF1',
#        u'LIF2', u'LIF3', u'LSF1', u'LSF2', u'LSF3', u'LSF4', u'LSF5',
#        u'LSF6', u'LSF7'],
#       dtype='<U5')
#   u'PST3']
#  [ array([u'G8', u'G21', u'G22', u'G23', u'G27', u'G29', u'G13', u'G14',
#        u'G31', u'G32', u'PST1', u'PST3', u'PPST1', u'PPST2', u'TO2',
#        u'TO3', u'TO4', u'TO5'],
#       dtype='<U5')
#   u'PST3'
#   array([u'G3', u'G4', u'G22', u'G29', u'G30', u'G31', u'G32', u'PPST3',
#        u'LSF2', u'LSF3', u'LSF4', u'LSF5'],
#       dtype='<U5')
#   u'PST3']
#  [ array([u'G22', u'G23', u'G29', u'G14', u'G32', u'PST1', u'PPST1', u'TO3'],
#       dtype='<U5')
#   u'PST3' array([u'G31', u'G32', u'LSF3', u'LSF4'],
#       dtype='<U4')
#   u'PST3']
#  [array([u'G22', u'G32', u'PST1', u'PPST1'],
#       dtype='<U5') u'PST3'
#   array([u'G31'],
#       dtype='<U3') u'PST3']
#  [array([u'PPST1'],
#       dtype='<U5') u'PST3'
#   array([u'G31'],
#       dtype='<U3') u'PST3']]
# pt16
# [[ array([u'OF1', u'OF2', u'OF3', u'TT5', u'MST2', u'MST3', u'PST1', u'PST2',
#        u'PST3', u'PST4', u'G4', u'G5', u'G6', u'G8', u'G12', u'G13',
#        u'G14', u'G15', u'G16', u'G18', u'G19', u'G20', u'G21', u'G22',
#        u'G23', u'G24', u'G26', u'G28', u'G29', u'G30', u'G31', u'G32'],
#       dtype='<U4')
#   array([u'OF2', u'MST1', u'PST1', u'PST2', u'PST3', u'PST4', u'AST1', u'G5',
#        u'G7', u'G14', u'G21', u'G23', u'G28', u'G29', u'G30', u'G31'],
#       dtype='<U4')
#   array([u'OF1', u'OF2', u'TT5', u'PST1', u'PST2', u'PST3', u'G5', u'G6',
#        u'G7', u'G19', u'G26', u'G28', u'G29'],
#       dtype='<U4')]
#  [ array([u'OF1', u'OF2', u'OF3', u'MST3', u'G4', u'G5', u'G6', u'G12',
#        u'G13', u'G14', u'G15', u'G16', u'G19', u'G20', u'G21', u'G22',
#        u'G24', u'G26', u'G28', u'G29', u'G30', u'G31', u'G32'],
#       dtype='<U4')
#   array([u'PST1', u'PST2', u'PST3', u'G5', u'G30'],
#       dtype='<U4')
#   array([u'OF1', u'OF2', u'PST3', u'G5', u'G6'],
#       dtype='<U4')]
#  [ array([u'OF2', u'OF3', u'G4', u'G5', u'G6', u'G12', u'G13', u'G15', u'G20',
#        u'G21', u'G22', u'G28', u'G30', u'G32'],
#       dtype='<U3')
#   array([u'PST2', u'PST3'],
#       dtype='<U4')
#   array([u'OF2', u'PST3'],
#       dtype='<U4')]
#  [array([u'OF2', u'G4', u'G12', u'G20', u'G21', u'G32'],
#       dtype='<U3')
#   array([u'PST3'],
#       dtype='<U4') array([u'OF2'],
#       dtype='<U3')]
#  [array([u'G20'],
#       dtype='<U3') array([u'PST3'],
#       dtype='<U4')
#   array([u'OF2'],
#       dtype='<U3')]]

# %%
pats = ['pt1', 'pt2', 'pt3', 'pt6', 'pt7', 'pt8', 'pt10', 'pt13', 'pt14', 'pt15']
for pat in pats:
    dataDir = '/Users/adam2392/Documents/adamli/fragility_dataanalysis/' + \
        'figures/fragilityStats/notchfilter/perturbationC_win250_step125_radius1.5/ictal_hardcoded/' + pat
    filelist = os.listdir(dataDir)
    
    # thresholds to set on the preictal, ictal times of coefficient of variation / other frag stats
    thresholds = [0.7, 0.8, 0.9, 0.95, 0.99]

    nih_row_doas = np.zeros((len(filelist), len(thresholds)))
    nih_post_doas = np.zeros((len(filelist), len(thresholds)))
    nih_ezsets = np.array(())
    nih_pats = []
    # Load each dataset's fragility statistics results
    for idx, fil in enumerate(filelist):
        datastruct = loadmat(os.path.join(dataDir, fil))
        features = datastruct['features_struct']

        colnames = features.keys()
        for col in colnames:
            try:
                features[col] = features[col]/max(features[col])
            except:
                1+1
    #             print col, " does not work"
        # extract all the fragility stats
        patient = features['patient']
        cfvar_time = features['cfvar_time']
        cfvar_chan = features['cfvar_chan']
        channels = features['included_labels']
        cezset = features['ezone_labels']

        # only if the dataset was ictal
        rowsum = features['rowsum']
        ez_90thresh = features['ez_90thresh_set']
        ez_95thresh = features['ez_95thresh_set']
        precfvar_chan = features['precfvar_chan']
        postcfvar_chan = features['postcfvar_chan']

        # extract the clinical meta data for this patient

        # go through each threshold and determine set of electrodes within EZ set 
        pat_post_doas = np.zeros((1, len(thresholds)))
        pat_row_doas = np.zeros((1, len(thresholds)))
        pat_ezsets = []
        for jdx, threshold in enumerate(thresholds):
            # get the indices that pass threshold for coefficient of variation
            post_ind = postcfvar_chan >= threshold
            row_inds = rowsum >= threshold
        
            # get the actual cv and the electrode name
            post_ezset = list(compress(channels, post_ind))
            row_ezset = list(compress(channels, row_inds))
            
            # compute doa
            post_doa_threshold = degreeofagree(post_ezset, cezset, channels)
            row_doa_threshold = degreeofagree(row_ezset, cezset, channels)
            
            # store the channel for this threshold
            pat_post_doas[0, jdx] = post_doa_threshold
            pat_row_doas[0, jdx] = row_doa_threshold
#             pat_ezsets.append(np.array(ezset))

        # convert the patient ez sets into an np array
#         pat_ezsets = np.array(pat_ezsets).reshape(len(thresholds), 1)

        # store the pats in a list
        nih_pats.append(patient)

        # store the pat ez sets 
#         if nih_ezsets.size == 0:
#             nih_ezsets = pat_ezsets
#         else:
#             nih_ezsets = np.append(nih_ezsets, pat_ezsets, axis=1)

        # store the pat doa into the center doa array
        nih_post_doas[idx, :] = pat_post_doas
        nih_row_doas[idx, :] = pat_row_doas

    fig = plt.figure(figsize=(7,7))
    ax = fig.add_subplot(211)
    plt.title('NIH Degree of Agreement Coefficient of Var for ' + pat)
    plt.xlabel('Threshold')
    plt.ylabel('Degree of Agreement')
    g = sns.boxplot(pd.DataFrame(nih_post_doas))
    xticklabels = g.get_xticklabels()
    g.set_xticklabels([str(threshold) for threshold in thresholds])
    
    ax = fig.add_subplot(212)
    plt.title('NIH Degree of Agreement Row Sum for ' + pat)
    plt.xlabel('Threshold')
    plt.ylabel('Degree of Agreement')
    g = sns.boxplot(pd.DataFrame(nih_row_doas))
    xticklabels = g.get_xticklabels()
    g.set_xticklabels([str(threshold) for threshold in thresholds])
    plt.tight_layout()
