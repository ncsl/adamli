# %%
import numpy as np
from numpy.linalg import norm
from math import sqrt
from scipy.sparse.linalg import eigs

# %matplotlib inline
import matplotlib.pylab as plt

# %% [markdown]
# ## Simulate Data

# %%
n_samples = 1000
n_features = 100

# initialize feature/data matrix
diag = np.random.rand(n_features)
A = np.random.multivariate_normal(np.zeros(n_features), np.diag(diag), n_samples)

# initialize real coefficients
realx = np.random.multivariate_normal(np.zeros(n_features), np.eye(n_features), 1).T

# create real observations Ax=b + some noise
white_noise = np.random.randn(n_samples,1)
b = A.dot(realx) + white_noise

print A.shape
print realx.shape
print b.shape

plt.plot(realx)
# Out:
# (1000, 100)
# (100, 1)
# (1000, 1)

# %% [markdown]
# ## Write Algorithm for Orgen Solver
#
# First script it.
#
# Second function it.
#
# Third class it.

# %%
# 0. initialize support set by solving 1/2 * l2norm + gamma/2*least_squares
x = (A.T*A +λI)^(−1)X.T*b


1/2 ||b − Ax||2 + λ/2||x||2
